# %% [markdown]
# # はじめにセグメンテーション

# %%
import numpy as np
from xml.etree import ElementTree
from xml.dom import minidom
import collections
import os
import matplotlib.pyplot as plt
import matplotlib as matplot
import seaborn as sns
# %matplotlib inline
import random
import cv2

#tokushimaの位置を指定する
#tokushimaの位置を指定する
dataset="drive_morning-0"
base_path = '/Users/gosato/Desktop/sekilab_3A2/models/research/deeplab/datasets/tokushima/drive_morning-0/'

# %%
file_names = []
files = open(base_path + "" + dataset + '.txt' , 'r')



for file in files:
    file = file.rstrip('\n')
    file_names.append(file)

# %%
# coding: utf-8

import os
from io import BytesIO
import tarfile
import tempfile
from six.moves import urllib

from matplotlib import gridspec
from matplotlib import pyplot as plt
import numpy as np
from PIL import Image

import tensorflow as tf


class DeepLabModel(object):
    INPUT_TENSOR_NAME = 'ImageTensor:0'
    OUTPUT_TENSOR_NAME = 'SemanticPredictions:0'
    INPUT_SIZE = 300
    FROZEN_GRAPH_NAME = 'frozen_inference_graph'

    def __init__(self, frozen_path):
        self.graph = tf.Graph()
        graph_def = None
        with open(frozen_path, 'rb') as f:
            graph_def = tf.GraphDef()
            graph_def.ParseFromString(f.read())
        if graph_def is None:
            raise RuntimeError('Cannot find inference graph in tar archive.')
        with self.graph.as_default():
            tf.import_graph_def(graph_def, name='')
        self.sess = tf.Session(graph=self.graph)

    def run(self, image):
        width, height = image.size
        resize_ratio = 1.0 * self.INPUT_SIZE / max(width, height)
        target_size = (int(resize_ratio * width), int(resize_ratio * height))
        resized_image = image.convert('RGB').resize(target_size, Image.ANTIALIAS)
        batch_seg_map = self.sess.run(
            self.OUTPUT_TENSOR_NAME,
            feed_dict={self.INPUT_TENSOR_NAME: [np.asarray(resized_image)]})
        seg_map = batch_seg_map[0]
        return resized_image, seg_map

    def returnSize(self,image):
        width, height = image.size
        resize_ratio = 1.0 * self.INPUT_SIZE / max(width, height)
        target_size = (int(resize_ratio * width), int(resize_ratio * height))
        return target_size


def create_pascal_label_colormap():
    """Creates a label colormap used in PASCAL VOC segmentation benchmark.

    Returns:
      A Colormap for visualizing segmentation results.
    """
    colormap = np.zeros((256, 3), dtype=int)
    ind = np.arange(256, dtype=int)

    for shift in reversed(range(8)):
        for channel in range(3):
            colormap[:, channel] |= ((ind >> channel) & 1) << shift
        ind >>= 3

    return colormap


def label_to_color_image(label):
    """Adds color defined by the dataset colormap to the label.

    Args:
      label: A 2D array with integer type, storing the segmentation label.

    Returns:
      result: A 2D array with floating type. The element of the array
        is the color indexed by the corresponding element in the input label
        to the PASCAL color map.

    Raises:
      ValueError: If label is not of rank 2 or its value is larger than color
        map maximum entry.
    """
    if label.ndim != 2:
        raise ValueError('Expect 2-D input label')

    colormap = create_pascal_label_colormap()

    if np.max(label) >= len(colormap):
        raise ValueError('label value too large.')

    return colormap[label]


def vis_segmentation(image, seg_map):
    """Visualizes input image, segmentation map and overlay view."""
    plt.figure(figsize=(15, 5))
    grid_spec = gridspec.GridSpec(1, 4, width_ratios=[6, 6, 6, 1])

    plt.subplot(grid_spec[0])
    plt.imshow(image)
    plt.axis('on')
    plt.title('input image')

    plt.subplot(grid_spec[1])
    seg_image = label_to_color_image(seg_map).astype(np.uint8)
    plt.imshow(seg_image)
    plt.axis('on')
    plt.title('segmentation map')

    plt.subplot(grid_spec[2])
    plt.imshow(image)
    plt.imshow(seg_image, alpha=0.7)
    plt.axis('on')
    plt.title('segmentation overlay')

    
    unique_labels = np.unique(seg_map)
    ax = plt.subplot(grid_spec[3])
    plt.imshow(FULL_COLOR_MAP[unique_labels].astype(np.uint8), interpolation='nearest')
    ax.yaxis.tick_right()
    plt.yticks(range(len(unique_labels)), LABEL_NAMES[unique_labels])
    plt.xticks([], [])
    ax.tick_params(width=0.0)
    plt.grid('off')
    plt.show()


# label setting

#ここの長さが4しかないことが問題
#いらないので省略する

LABEL_NAMES = np.full(150,"other")
LABEL_NAMES[7]="road"
LABEL_NAMES[12]="pavement"
FULL_LABEL_MAP = np.arange(len(LABEL_NAMES)).reshape(len(LABEL_NAMES), 1)
FULL_COLOR_MAP = label_to_color_image(FULL_LABEL_MAP)


def show_segmentation(i):

    #見たい画像のパス

    image_file=base_path + "" + file_names[i]
    img_path = image_file

    
    #deeplab_graph.pbの位置
    model_path ="/Users/gosato/Desktop/sekilab_3A2/models/research/deeplab/deeplab_graph.pb"

    # load model
    model = DeepLabModel(model_path)

    # read image
    original_im = Image.open(img_path)

    # inferences DeepLab model
    resized_im, seg_map = model.run(original_im)
    
    # show inference result
    vis_segmentation(resized_im, seg_map)

    
def get_segmentation(i):
    
    image_file=base_path + "" + file_names[i]
    img_path = image_file
    
    
    #deeplab_graph.pbの位置
    model_path = "/Users/gosato/Desktop/sekilab_3A2/models/research/deeplab/deeplab_graph.pb"

    # load model
    model = DeepLabModel(model_path)

    # read image
    original_im = Image.open(img_path)

    # inferences DeepLab model
    resized_im, seg_map = model.run(original_im)
    
    return seg_map

def get_all_segmentation():
    seg_maps=[]
    for i in range(0,len(file_names)):
        seg_map=get_segmentation(i)
        seg_maps.append(seg_map)
        print(str(i)+"/"+str(len(file_names)))
    return seg_maps

# %%
i=66

show_segmentation(i)
# Out:
# /anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %%
seg_maps=get_all_segmentation()
#時間がかかるので注意！
# Out:
# 0/125
# 1/125
# 2/125
# 3/125
# 4/125
# 5/125
# 6/125
# 7/125
# 8/125
# 9/125
# 10/125
# 11/125
# 12/125
# 13/125
# 14/125
# 15/125
# 16/125
# 17/125
# 18/125
# 19/125
# 20/125
# 21/125
# 22/125
# 23/125
# 24/125
# 25/125
# 26/125
# 27/125
# 28/125
# 29/125
# 30/125
# 31/125
# 32/125
# 33/125
# 34/125
# 35/125
# 36/125
# 37/125
# 38/125
# 39/125
# 40/125
# 41/125
# 42/125
# 43/125
# 44/125
# 45/125
# 46/125
# 47/125
# 48/125
# 49/125
# 50/125
# 51/125
# 52/125
# 53/125
# 54/125
# 55/125
# 56/125
# 57/125
# 58/125
# 59/125
# 60/125
# 61/125
# 62/125
# 63/125
# 64/125
# 65/125
# 66/125
# 67/125
# 68/125
# 69/125
# 70/125
# 71/125
# 72/125
# 73/125
# 74/125
# 75/125
# 76/125
# 77/125
# 78/125
# 79/125
# 80/125
# 81/125
# 82/125
# 83/125
# 84/125
# 85/125
# 86/125
# 87/125
# 88/125
# 89/125
# 90/125
# 91/125
# 92/125
# 93/125
# 94/125
# 95/125
# 96/125
# 97/125
# 98/125
# 99/125
# 100/125
# 101/125
# 102/125
# 103/125
# 104/125
# 105/125
# 106/125
# 107/125
# 108/125
# 109/125
# 110/125
# 111/125
# 112/125
# 113/125
# 114/125
# 115/125
# 116/125
# 117/125
# 118/125
# 119/125
# 120/125
# 121/125
# 122/125
# 123/125
# 124/125

# %%
seg_maps[0][12][160]


#y,xの順
# Out:
# 3

# %% [markdown]
# # 直線検出プログラム

# %%
    
    
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline




minLineLength=100
maxLineGap=3

def make_lines(minLineLength,maxLineGap):
    lines=[]
    for i in range(0,len(file_names)):        
        image_file=base_path + "" + file_names[i]
        #print(image_file)
        img = cv2.imread(image_file)
        #img=cv2.resize(img,(600,600))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        #edges = cv2.Canny(gray,50,150,apertureSize = 3)
        edges = cv2.Canny(gray,300,500,apertureSize = 3)
        line = cv2.HoughLinesP(edges,rho=1,theta=np.pi/360,threshold=100,minLineLength=minLineLength,maxLineGap=maxLineGap)
        if line is None:
            lines.append([])
        else:
            lines.append(line)
    return lines

            
            #この関数には問題はない！

# %%
lines=make_lines(minLineLength,maxLineGap)

# %%
def check_in_road(x,y,seg_map,width=1):
    seg_map_x_len=len(seg_map)
    seg_map_y_len=len(seg_map[0])
    
    if (x//2-width)<0:
        x_min=0
    else:
        x_min=x//2-width
        
    if (y//2-width)<0:
        y_min=0
    else:
        y_min=y//2-width
        
    if (x//2+width)>seg_map_x_len:
        x_max=seg_map_x_len
    else:
        x_max=x//2+width
        
    if (y//2+width)>seg_map_y_len:
        y_max=seg_map_y_len
    else:
        y_max=y//2+width
    
    for p in range(x_min,x_max):
        for q in range(y_min,y_max):
            if seg_map[q,p]==7:
                return True
        
    return False

# %%
def choose_right_up_lines(lines,i,dx_min=30,dy_min=30,seg_maps=seg_maps):
    right_up_lines=[]
    seg_map=seg_maps[i]
    hoo=0
    while hoo<len(lines):

        x1, y1, x2, y2 = lines[hoo][0]

        if ((x2-x1)>dx_min and (y2-y1)<(-1)*dy_min):
            #直線は少しは右上がりである

            if check_in_road(x1,y1,seg_map):
                #左下の点が道路領域に入っている
                #まずはx1=0となるように延長
                new_x1=0
                new_y1=int(y2+(y1-y2)*(x2/(x2-x1)))
                if new_y1>=600:
                    #y>=600になってしまった場合はy=599で止める
                    new_y1=599
                    new_x1=int((x2-(x2-x1)*((599-y2)/(y1-y2))))
                
                if check_in_road(x2,y2,seg_map):
  
                    #右上の点が道路領域に入っている
                    #直線を延長する
                    dx2=10
                    new_x2=x2
                    new_y2=y2
                    while (new_y2>100 and new_x2<500):
 
                        #new_y2すなわち右上点のy座標はは100より大きい
                        #右上点のx座標は500よりは小さい
                        new_x2_next=new_x2+dx2
  
                        new_y2_next=int(y1-(y1-y2)*((new_x2_next-x1)/(x2-x1)))
                        if check_in_road(new_x2_next,new_y2_next,seg_map):
   
                            new_x2=new_x2_next
                            new_y2=new_y2_next
                        else:
                            break
                
                else:
                    #右上の点が道路領域に入っていない
                    #直線を短くする

                    dx2=10
                    new_x2=x2
                    new_y2=y2
                    while new_x2>(new_x1+dx_min):
                        #new_x2すなわち右上点のx座標はnew_x1+dx_minより小さくならない
                        new_x2_next=new_x2-dx2
                        new_y2_next=int(y1-(y1-y2)*((new_x2_next-x1)/(x2-x1)))
                        if check_in_road(new_x2_next,new_y2_next,seg_map):
                            new_x2=new_x2_next
                            new_y2=new_y2_next
                        else:
                            break
                        
                #確定                
                x1,y1,x2,y2=new_x1,new_y1,new_x2,new_y2
                hoo+=1
                
                                
                        
            else:
                #左下の点が道路領域に入っていない  

                
                hoo+=1
        else:
            #直線は右上がりではない
            hoo+=1
                    
        
        if (x2-x1)>(dx_min):
            if (y2-y1)<(-1)*(dy_min):
                right_up_lines.append([[x1,y1,x2,y2]])
                                
        
                                
    return right_up_lines

# %%
choose_right_up_lines(lines[0],0,dx_min=10,dy_min=10,seg_maps=seg_maps)
# Out:
# [[[37, 599, 333, 234]], [[154, 176, 181, 46]]]

# %%
def choose_right_down_lines(lines,i,dx_min=30,dy_min=30,seg_maps=seg_maps):
    right_up_lines=[]
    seg_map=seg_maps[i]
    hoo=0
    while hoo<len(lines):
        x1, y1, x2, y2 = lines[hoo][0]

        
        if ((x2-x1)>dx_min and (y2-y1)>dy_min):
            #直線は少しは右下がりである
            if check_in_road(x2,y2,seg_map):
                #右下の点が道路領域に入っている
                #まずはx2=599となるように延長
                new_x2=599
                new_y2=int(y1+(y2-y1)*((599-x1)/(x2-x1)))
                if new_y2>=600:
                    #y>=600になってしまった場合はy=599で止める
                    new_y2=599
                    new_x2=int((x1+(x2-x1)*((599-y1)/(y2-y1))))
                
                if check_in_road(x1,y1,seg_map):
                    #左上の点が道路領域に入っている
                    #直線を延長する

                    
                    dx1=10
                    new_x1=x1
                    new_y1=y1
                    while (new_y1>100 and new_x1>100):
                        
                        
                        new_x1_next=new_x1-dx1
                        new_y1_next=int(y1-(y2-y1)*((x1-new_x1_next)/(x2-x1)))
                        if check_in_road(new_x1_next,new_y1_next,seg_map):
                            new_x1=new_x1_next
                            new_y1=new_y1_next
                        else:
                            break
                
                else:
                    #左上の点が道路領域に入っていない
                    #直線を短くする
 

                    dx1=10
                    new_x1=x1
                    new_y1=y1
                    while new_x2>(new_x1+dx_min):
                        new_x1_next=new_x1+dx1
                        new_y1_next=int(y2-(y2-y1)*((x2-new_x1_next)/(x2-x1)))
                            
                        if check_in_road(new_x1_next,new_y1_next,seg_map):
                            new_x1=new_x1_next
                            new_y1=new_y1_next
                        else:
                            break
                        
                #確定                
                x1,y1,x2,y2=new_x1,new_y1,new_x2,new_y2
                hoo+=1
                                       
            else:
                #右下の点が道路領域にない
  

                hoo+=1
        else:
            
            hoo+=1
                    
        
        if (x2-x1)>(dx_min):
            if (y2-y1)>1*(dy_min):
                right_up_lines.append([[x1,y1,x2,y2]])
                                
        
                                
    return right_up_lines

# %%
def trapezoid_score (x_top_left,x_top_right,x_bottom_left,x_bottom_right,y_top,y_bottom):
    height_of_trapezoid=y_bottom-y_top
    #score=size_of_trapezoid(x_top_left,x_top_right,x_bottom_left,x_bottom_right,y_top,y_bottom)
    score=size_of_trapezoid(x_top_left,x_top_right,x_bottom_left,x_bottom_right,y_top,y_bottom)+(height_of_trapezoid**2)
    
    return score

def size_of_trapezoid (x_top_left,x_top_right,x_bottom_left,x_bottom_right,y_top,y_bottom):
    #台形の面積を求める
    top_length=x_top_right-x_top_left
    bottom_length=x_bottom_right-x_bottom_left
    height_of_trapezoid=y_bottom-y_top
    size=(top_length+bottom_length)*height_of_trapezoid/2
    return size

# %%
def decide_left_and_right_lines(lines):
    #適切な台形がない場合は前の画像のものが使い回される
    left_lines=[]
    right_lines=[]
    sizes=[]

    init_left_line= [(0,1,2,3)]
    init_right_line=[(0,1,2,3)]
    init_size=0
    temp_left_line=init_left_line
    temp_right_line=init_right_line
    temp_size=init_size
        
    for i in range(0,len(file_names)):
        
        temp_lines=lines[i]
        
        if i==0:            
            temp_already_changed=False
        else:
            temp_left_line=left_lines[i-1]
            temp_right_line=right_lines[i-1]
            temp_size=0
            temp_already_changed=False
            
        right_up_lines=choose_right_up_lines(temp_lines,i)
        
        right_down_lines=choose_right_down_lines(temp_lines,i)
        

        
        for j in range(0,len(right_up_lines)):
            for k in range(0,len(right_down_lines)):
            
                check_left_line=right_up_lines[j]    
                check_right_line=right_down_lines[k]    
                
            
                if temp_already_changed:
                
                    x1, y1, x2, y2 = check_left_line[0]
                    x3, y3, x4, y4 = check_right_line[0]
                    x5, y5, x6, y6 = temp_left_line[0]
                    x7, y7, x8, y8 = temp_right_line[0]
                
                    len_left_new=((x2-x1)**2+(y2-y1)**2)
                    len_right_new=((x4-x3)**2+(y4-y3)**2)
                    len_left_temp=((x6-x5)**2+(y6-y5)**2)
                    len_right_temp=((x8-x7)**2+(y8-y7)**2)
                
                    if y2<=y3:
                        if y1<=y4:
                            y_top=y3
                            y_bottom=y1
                            x_top_left=int(x1+(x2-x1)*((y3-y1)/(y2-y1)))
                            x_top_right=x3
                            x_bottom_left=x1
                            x_bottom_right=int(x3+(x4-x3)*((y1-y3)/(y4-y3)))
                        else:
                            y_top=y3
                            y_bottom=y4
                            x_top_left=int(x1+(x2-x1)*((y3-y1)/(y2-y1)))
                            x_top_right=x3
                            x_bottom_left=int(x1+(x2-x1)*((y4-y1)/(y2-y1)))
                            x_bottom_right=x4
                    else:
                        if y1<=y4:
                            y_top=y2
                            y_bottom=y1
                            x_top_left=x2
                            x_top_right=int(x3+(x4-x3)*((y2-y3)/(y4-y3)))
                            x_bottom_left=x1
                            x_bottom_right=int(x3+(x4-x3)*((y1-y3)/(y4-y3)))
                        else:
                            y_top=y2
                            y_bottom=y4
                            x_top_left=x2
                            x_top_right=int(x3+(x4-x3)*((y2-y3)/(y4-y3)))
                            x_bottom_left=int(x1+(x2-x1)*((y4-y1)/(y2-y1)))
                            x_bottom_right=x4
                            
                    check_size=trapezoid_score(x_top_left,x_top_right,x_bottom_left,x_bottom_right,y_top,y_bottom)
                    
                    if ((y_bottom-y_top)>100 and (x_top_right-x_top_left)>1 and (x_bottom_right-x_bottom_left)>((x_top_right-x_top_left)+10)):
                        if  check_size>temp_size:
            

                            temp_left_line=check_left_line
                            temp_right_line=check_right_line
                            temp_size=check_size
                            
                    
                    
                else:
                
                    x1, y1, x2, y2 = check_left_line[0]
                    x3, y3, x4, y4 = check_right_line[0]
                    x5, y5, x6, y6 = temp_left_line[0]
                    x7, y7, x8, y8 = temp_right_line[0]
                
                    len_left_new=((x2-x1)**2+(y2-y1)**2)
                    len_right_new=((x4-x3)**2+(y4-y3)**2)
                    len_left_temp=((x6-x5)**2+(y6-y5)**2)
                    len_right_temp=((x8-x7)**2+(y8-y7)**2)
                
                    if y2<=y3:
                        if y1<=y4:
                            y_top=y3
                            y_bottom=y1
                            x_top_left=int(x1+(x2-x1)*((y3-y1)/(y2-y1)))
                            x_top_right=x3
                            x_bottom_left=x1
                            x_bottom_right=int(x3+(x4-x3)*((y1-y3)/(y4-y3)))
                        else:
                            y_top=y3
                            y_bottom=y4
                            x_top_left=int(x1+(x2-x1)*((y3-y1)/(y2-y1)))
                            x_top_right=x3
                            x_bottom_left=int(x1+(x2-x1)*((y4-y1)/(y2-y1)))
                            x_bottom_right=x4
                    else:
                        if y1<=y4:
                            y_top=y2
                            y_bottom=y1
                            x_top_left=x2
                            x_top_right=int(x3+(x4-x3)*((y2-y3)/(y4-y3)))
                            x_bottom_left=x1
                            x_bottom_right=int(x3+(x4-x3)*((y1-y3)/(y4-y3)))
                        else:
                            y_top=y2
                            y_bottom=y4
                            x_top_left=x2
                            x_top_right=int(x3+(x4-x3)*((y2-y3)/(y4-y3)))
                            x_bottom_left=int(x1+(x2-x1)*((y4-y1)/(y2-y1)))
                            x_bottom_right=x4
                        
                    check_size=trapezoid_score(x_top_left,x_top_right,x_bottom_left,x_bottom_right,y_top,y_bottom)
                
                    if ((y_bottom-y_top)>100 and (x_top_right-x_top_left)>1 and (x_bottom_right-x_bottom_left)>((x_top_right-x_top_left)+10)):
                        temp_left_line=check_left_line
                        temp_right_line=check_right_line
                        temp_size=check_size
                        temp_already_changed=True
  
                        
        left_lines.append(temp_left_line)
        right_lines.append(temp_right_line)
        sizes.append(temp_size)
            
        print(str(i)+"/"+str(len(lines)))
                        
    
    left_lines=[]
    right_lines=[]
    sizes=[]

    for i in range(0,len(file_names)):
   
        temp_lines=lines[i]
        
        
        
        if i==0:            
            temp_already_changed=False
        else:
            temp_left_line=left_lines[i-1]
            temp_right_line=right_lines[i-1]
            temp_size=0
            temp_already_changed=False
            
        right_up_lines=choose_right_up_lines(temp_lines,i)
        right_down_lines=choose_right_down_lines(temp_lines,i)
        
        
        for j in range(0,len(right_up_lines)):
            for k in range(0,len(right_down_lines)):
            
                check_left_line=right_up_lines[j]    
                check_right_line=right_down_lines[k]    
            
                if temp_already_changed:
                
                    x1, y1, x2, y2 = check_left_line[0]
                    x3, y3, x4, y4 = check_right_line[0]
                    x5, y5, x6, y6 = temp_left_line[0]
                    x7, y7, x8, y8 = temp_right_line[0]
                
                    len_left_new=((x2-x1)**2+(y2-y1)**2)
                    len_right_new=((x4-x3)**2+(y4-y3)**2)
                    len_left_temp=((x6-x5)**2+(y6-y5)**2)
                    len_right_temp=((x8-x7)**2+(y8-y7)**2)
                    
                
                    if y2<=y3:
                        if y1<=y4:
                            y_top=y3
                            y_bottom=y1
                            x_top_left=int(x1+(x2-x1)*((y3-y1)/(y2-y1)))
                            x_top_right=x3
                            x_bottom_left=x1
                            x_bottom_right=int(x3+(x4-x3)*((y1-y3)/(y4-y3)))
                        else:
                            y_top=y3
                            y_bottom=y4
                            x_top_left=int(x1+(x2-x1)*((y3-y1)/(y2-y1)))
                            x_top_right=x3
                            x_bottom_left=int(x1+(x2-x1)*((y4-y1)/(y2-y1)))
                            x_bottom_right=x4
                    else:
                        if y1<=y4:
                            y_top=y2
                            y_bottom=y1
                            x_top_left=x2
                            x_top_right=int(x3+(x4-x3)*((y2-y3)/(y4-y3)))
                            x_bottom_left=x1
                            x_bottom_right=int(x3+(x4-x3)*((y1-y3)/(y4-y3)))
                        else:
                            y_top=y2
                            y_bottom=y4
                            x_top_left=x2
                            x_top_right=int(x3+(x4-x3)*((y2-y3)/(y4-y3)))
                            x_bottom_left=int(x1+(x2-x1)*((y4-y1)/(y2-y1)))
                            x_bottom_right=x4
  
                    check_size=trapezoid_score(x_top_left,x_top_right,x_bottom_left,x_bottom_right,y_top,y_bottom)
                    if ((y_bottom-y_top)>100 and (x_top_right-x_top_left)>1 and (x_bottom_right-x_bottom_left)>((x_top_right-x_top_left)+10)):
                        if  check_size>temp_size:
            

                            temp_left_line=check_left_line
                            temp_right_line=check_right_line
                            temp_size=check_size
                            
                    
                    
                    
                else:
                
                    x1, y1, x2, y2 = check_left_line[0]
                    x3, y3, x4, y4 = check_right_line[0]
                    x5, y5, x6, y6 = temp_left_line[0]
                    x7, y7, x8, y8 = temp_right_line[0]
                
                    len_left_new=((x2-x1)**2+(y2-y1)**2)
                    len_right_new=((x4-x3)**2+(y4-y3)**2)
                    len_left_temp=((x6-x5)**2+(y6-y5)**2)
                    len_right_temp=((x8-x7)**2+(y8-y7)**2)
                
                    if y2<=y3:
                        if y1<=y4:
                            y_top=y3
                            y_bottom=y1
                            x_top_left=int(x1+(x2-x1)*((y3-y1)/(y2-y1)))
                            x_top_right=x3
                            x_bottom_left=x1
                            x_bottom_right=int(x3+(x4-x3)*((y1-y3)/(y4-y3)))
                        else:
                            y_top=y3
                            y_bottom=y4
                            x_top_left=int(x1+(x2-x1)*((y3-y1)/(y2-y1)))
                            x_top_right=x3
                            x_bottom_left=int(x1+(x2-x1)*((y4-y1)/(y2-y1)))
                            x_bottom_right=x4
                    else:
                        if y1<=y4:
                            y_top=y2
                            y_bottom=y1
                            x_top_left=x2
                            x_top_right=int(x3+(x4-x3)*((y2-y3)/(y4-y3)))
                            x_bottom_left=x1
                            x_bottom_right=int(x3+(x4-x3)*((y1-y3)/(y4-y3)))
                        else:
                            y_top=y2
                            y_bottom=y4
                            x_top_left=x2
                            x_top_right=int(x3+(x4-x3)*((y2-y3)/(y4-y3)))
                            x_bottom_left=int(x1+(x2-x1)*((y4-y1)/(y2-y1)))
                            x_bottom_right=x4
                        
                    check_size=trapezoid_score(x_top_left,x_top_right,x_bottom_left,x_bottom_right,y_top,y_bottom)
                    if ((y_bottom-y_top)>100 and (x_top_right-x_top_left)>1 and (x_bottom_right-x_bottom_left)>((x_top_right-x_top_left)+10)):
                       
                        temp_left_line=check_left_line
                        temp_right_line=check_right_line
                        temp_size=check_size
                        temp_already_changed=True
                        
                        
                        
        left_lines.append(temp_left_line)
        right_lines.append(temp_right_line)
        sizes.append(temp_size)
        
        print(str(i)+"/"+str(len(lines)))
    
 
    return (left_lines,right_lines)

# %%
left_lines,right_lines=decide_left_and_right_lines(lines)
# Out:
# 0/125
# 1/125
# 2/125
# 3/125
# 4/125
# 5/125
# 6/125
# 7/125
# 8/125
# 9/125
# 10/125
# 11/125
# 12/125
# 13/125
# 14/125
# 15/125
# 16/125
# 17/125
# 18/125
# 19/125
# 20/125
# 21/125
# 22/125
# 23/125
# 24/125
# 25/125
# 26/125
# 27/125
# 28/125
# 29/125
# 30/125
# 31/125
# 32/125
# 33/125
# 34/125
# 35/125
# 36/125
# 37/125
# 38/125
# 39/125
# 40/125
# 41/125
# 42/125
# 43/125
# 44/125
# 45/125
# 46/125
# 47/125
# 48/125
# 49/125
# 50/125
# 51/125
# 52/125
# 53/125
# 54/125
# 55/125
# 56/125
# 57/125
# 58/125
# 59/125
# 60/125
# 61/125
# 62/125
# 63/125
# 64/125
# 65/125
# 66/125
# 67/125
# 68/125
# 69/125
# 70/125
# 71/125
# 72/125
# 73/125
# 74/125
# 75/125
# 76/125
# 77/125
# 78/125
# 79/125
# 80/125
# 81/125
# 82/125
# 83/125
# 84/125
# 85/125
# 86/125
# 87/125
# 88/125
# 89/125
# 90/125
# 91/125
# 92/125
# 93/125
# 94/125
# 95/125
# 96/125
# 97/125
# 98/125
# 99/125
# 100/125
# 101/125
# 102/125
# 103/125
# 104/125
# 105/125
# 106/125
# 107/125
# 108/125
# 109/125
# 110/125
# 111/125
# 112/125
# 113/125
# 114/125
# 115/125
# 116/125
# 117/125
# 118/125
# 119/125
# 120/125
# 121/125
# 122/125
# 123/125
# 124/125
# 0/125
# 1/125
# 2/125
# 3/125
# 4/125
# 5/125
# 6/125
# 7/125
# 8/125
# 9/125
# 10/125
# 11/125
# 12/125
# 13/125
# 14/125
# 15/125
# 16/125
# 17/125
# 18/125
# 19/125
# 20/125
# 21/125
# 22/125
# 23/125
# 24/125
# 25/125
# 26/125
# 27/125
# 28/125
# 29/125
# 30/125
# 31/125
# 32/125
# 33/125
# 34/125
# 35/125
# 36/125
# 37/125
# 38/125
# 39/125
# 40/125
# 41/125
# 42/125
# 43/125
# 44/125
# 45/125
# 46/125
# 47/125
# 48/125
# 49/125
# 50/125
# 51/125
# 52/125
# 53/125
# 54/125
# 55/125
# 56/125
# 57/125
# 58/125
# 59/125
# 60/125
# 61/125
# 62/125
# 63/125
# 64/125
# 65/125
# 66/125
# 67/125
# 68/125
# 69/125
# 70/125
# 71/125
# 72/125
# 73/125
# 74/125
# 75/125
# 76/125
# 77/125
# 78/125
# 79/125
# 80/125
# 81/125
# 82/125
# 83/125
# 84/125
# 85/125
# 86/125
# 87/125
# 88/125
# 89/125
# 90/125
# 91/125
# 92/125
# 93/125
# 94/125
# 95/125
# 96/125
# 97/125
# 98/125
# 99/125
# 100/125
# 101/125
# 102/125
# 103/125
# 104/125
# 105/125
# 106/125
# 107/125
# 108/125
# 109/125
# 110/125
# 111/125
# 112/125
# 113/125
# 114/125
# 115/125
# 116/125
# 117/125
# 118/125
# 119/125
# 120/125
# 121/125
# 122/125
# 123/125
# 124/125

# %%
def decide_final_trapezoids(left_lines,right_lines):
    trapezoids=[]
    for i in range(len(file_names)):
        x1, y1, x2, y2 = left_lines[i][0]
        x3, y3, x4, y4 = right_lines[i][0]
        if y2<=y3:
            if y1<=y4:
                y_top=y3
                y_bottom=y1
                x_top_left=int(x1+(x2-x1)*((y3-y1)/(y2-y1)))
                x_top_right=x3
                x_bottom_left=x1
                x_bottom_right=int(x3+(x4-x3)*((y1-y3)/(y4-y3)))
            else:
                y_top=y3
                y_bottom=y4
                x_top_left=int(x1+(x2-x1)*((y3-y1)/(y2-y1)))
                x_top_right=x3
                x_bottom_left=int(x1+(x2-x1)*((y4-y1)/(y2-y1)))
                x_bottom_right=x4
        else:
            if y1<=y4:
                y_top=y2
                y_bottom=y1
                x_top_left=x2
                x_top_right=int(x3+(x4-x3)*((y2-y3)/(y4-y3)))
                x_bottom_left=x1
                x_bottom_right=int(x3+(x4-x3)*((y1-y3)/(y4-y3)))
            else:
                y_top=y2
                y_bottom=y4
                x_top_left=x2
                x_top_right=int(x3+(x4-x3)*((y2-y3)/(y4-y3)))
                x_bottom_left=int(x1+(x2-x1)*((y4-y1)/(y2-y1)))
                x_bottom_right=x4
        if (x_top_right-x_top_left<=100):
            #print(i)
            while (x_top_right-x_top_left<=100):
                #print(i)
                y_top+=1
                x_top_left=int(x1+(x2-x1)*((y_top-y1)/(y2-y1)))
                x_top_right=int(x3+(x4-x3)*((y_top-y3)/(y4-y3)))
                
                #台形上部の幅は100より大きい
                
        
                
        trapezoids.append([x_top_left,x_top_right,x_bottom_left,x_bottom_right,y_top,y_bottom])
    return(trapezoids)

# %%
def decide_trapezoids(left_lines,right_lines):
    #古いコード
    trapezoids=[]
    for i in range(len(file_names)):
        x1, y1, x2, y2 = left_lines[i][0]
        x3, y3, x4, y4 = right_lines[i][0]
        if y2<=y3:
            if y1<=y4:
                y_top=y3
                y_bottom=y1
                x_top_left=int(x1+(x2-x1)*((y3-y1)/(y2-y1)))
                x_top_right=x3
                x_bottom_left=x1
                x_bottom_right=int(x3+(x4-x3)*((y1-y3)/(y4-y3)))
            else:
                y_top=y3
                y_bottom=y4
                x_top_left=int(x1+(x2-x1)*((y3-y1)/(y2-y1)))
                x_top_right=x3
                x_bottom_left=int(x1+(x2-x1)*((y4-y1)/(y2-y1)))
                x_bottom_right=x4
        else:
            if y1<=y4:
                y_top=y2
                y_bottom=y1
                x_top_left=x2
                x_top_right=int(x3+(x4-x3)*((y2-y3)/(y4-y3)))
                x_bottom_left=x1
                x_bottom_right=int(x3+(x4-x3)*((y1-y3)/(y4-y3)))
            else:
                y_top=y2
                y_bottom=y4
                x_top_left=x2
                x_top_right=int(x3+(x4-x3)*((y2-y3)/(y4-y3)))
                x_bottom_left=int(x1+(x2-x1)*((y4-y1)/(y2-y1)))
                x_bottom_right=x4
        
                
        trapezoids.append([x_top_left,x_top_right,x_bottom_left,x_bottom_right,y_top,y_bottom])
    return(trapezoids)

# %%
trapezoids=decide_final_trapezoids(left_lines,right_lines)

# %%
def draw_images(trapezoids,x_split,y_split,i):
    
    trapezoid=trapezoids[i]
    
    img = cv2.imread(base_path + "" + file_names[i])   
                      
    x_top_left=trapezoid[0]
    x_top_right=trapezoid[1]
    x_bottom_left=trapezoid[2]
    x_bottom_right=trapezoid[3]
    y_top=trapezoid[4]
    y_bottom=trapezoid[5]
    
    pts = np.array([[x_top_left,y_top],[x_bottom_left,y_bottom],[x_bottom_right,y_bottom],[x_top_right,y_top]])
    
    cv2.polylines(img,[pts],True,(0,255,255),2)
    
    pts2=[]
    
    #grid_xとして許される最大値はx_split-1
    grid_x_max=x_split-1
    #グリッドのxの値を初期値1に設定
    grid_x=1
    
    while grid_x<=grid_x_max:
        #現在のgrid_xについてグリッド上下端の座標を決定する
        x_top_line=int(x_top_left+(x_top_right-x_top_left)*(grid_x/x_split))
        x_bottom_line=int(x_bottom_left+(x_bottom_right-x_bottom_left)*(grid_x/x_split))
        pts2.append([[x_top_line,y_top],[x_bottom_line,y_bottom]])
        grid_x+=1
 
    grid_y_max=y_split-1
    grid_y=1
    
    while grid_y<=grid_y_max:
        
        x_left_line=int(x_top_left+(x_bottom_left-x_top_left)*(grid_y/y_split))
        x_right_line=int(x_top_right+(x_bottom_right-x_top_right)*(grid_y/y_split))
        y_line=int(y_top+(y_bottom-y_top)*(grid_y/y_split))
        pts2.append([[x_left_line,y_line],[x_right_line,y_line]])
        grid_y+=1
    
    for line in pts2:
        
        line=np.array(line)
        cv2.polylines(img,[line],True,(0,255,255),2)
    
    
    return img

# %%
x_split =10
y_split =10

# %%
#print(trapezoids)

# %%
fig=plt.figure(figsize=(6,6))

i=5
img = draw_images(trapezoids,x_split,y_split,i)
plt.axis('on')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

print(trapezoids[i])
# Out:
# [291, 393, 175, 599, 279, 419]

# %%
x1, y1, x2, y2 = left_lines[i][0]
x3, y3, x4, y4 = right_lines[i][0]

pts=[]
pts.append([[x1,y1],[x2,y2]])
pts.append([[x3,y3],[x4,y4]])
    
for line in pts:
    line=np.array(line)
    cv2.polylines(img,[line],True,(255,255,0),3)
print(left_lines[i][0])
print(right_lines[i][0])




yellow_line_img=cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
cv2.imwrite("output2.jpg", yellow_line_img)


img = cv2.imread("output2.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(6,6))
plt.imshow(img)
# Out:
# [27, 599, 322, 242]
# [332, 237, 599, 419]

# %% [markdown]
# # グリッドを50cm四方に

# %%
import numpy as np
import pandas as pd
import cv2
import os
import glob
import matplotlib.pyplot as plt
import pickle

# %matplotlib inline

# %%
base_path_2 = '/Users/gosato/Desktop/sekilab_3A2/Curved-Lane-Lines/'

# %%
    
    
def undistort_img():
    # Prepare object points 0,0,0 ... 8,5,0
    obj_pts = np.zeros((10*7,3), np.float32)
    #obj_pts[:,:2] = np.mgrid[0:7, 0:10].T.reshape(-1,2)
    #これを物理単位にしないとダメそう
    
    obj_pts[:,:2] = np.mgrid[0:7, 0:10].T.reshape(-1,2)*2.2E-03
    #物理単位(m)に変更
    

    # Stores all object points & img points from all images
    objpoints = []
    imgpoints = []

    
    # Get directory for all calibration images
    
    
    #このフォルダ内のたくさんのチェスボード画像がキャリブレーションに使われる
    
    
    
    images = glob.glob(base_path_2+'camera_cal/*.jpg')
    
    #ここを絶対コードにすれば良い
    
    #print(images)

    for indx, fname in enumerate(images):
        img = cv2.imread(fname)
        
        #img=cv2.resize(img,(600,600))
        
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        ret, corners = cv2.findChessboardCorners(gray, (7,10), None)

        if ret == True:
            objpoints.append(obj_pts)
            imgpoints.append(corners)
    # Test undistortion on img
    img_size = (img.shape[1], img.shape[0])
    #img_size = (600,600)

    #print(objpoints)
    # Calibrate camera
    ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, img_size, None,None)
    
    print(mtx)

    dst = cv2.undistort(img, mtx, dist, None, mtx)
    # Save camera calibration for later use
    dist_pickle = {}
    dist_pickle['mtx'] = mtx
    dist_pickle['dist'] = dist
    pickle.dump( dist_pickle, open(base_path_2+'camera_cal/calibration1.p', 'wb') )
    
    #保存
    
    


    
def undistort(img, cal_dir=base_path_2+'camera_cal/calibration1.p'):
    #cv2.imwrite('camera_cal_old/test_cal.jpg', dst)
    with open(cal_dir, mode='rb') as f:
        file = pickle.load(f)
    mtx = file['mtx']
    dist = file['dist']
    dst = cv2.undistort(img, mtx, dist, None, mtx)
    
    return dst

# %%
undistort_img()
# Out:
# [[1.93553166e+03 0.00000000e+00 3.34521216e+02]
#  [0.00000000e+00 1.94625742e+03 4.90428178e+02]
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00]]

# %%
img = cv2.imread(base_path + "" + file_names[i])   

#img=cv2.resize(img,(600,600))

#img = cv2.imread('test_images/test3.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
dst = undistort(img)


# Visualize undistortion
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))
ax1.imshow(img)
ax1.set_title('Original Image', fontsize=30)
ax2.imshow(dst)
ax2.set_title('Undistorted Image', fontsize=30)
# Out:
# Text(0.5, 1.0, 'Undistorted Image')

# %%
#以下は一旦カメラの歪みはないと仮定して進める

# %%
def get_mtx(cal_dir=base_path_2+'camera_cal/calibration1.p'):
    #cv2.imwrite('camera_cal_old/test_cal.jpg', dst)
    with open(cal_dir, mode='rb') as f:
        file = pickle.load(f)
    mtx = file['mtx']
    
    return mtx

# %%
mtx=get_mtx()

# %%
mtx
# Out:
# array([[1.93553166e+03, 0.00000000e+00, 3.34521216e+02],
#        [0.00000000e+00, 1.94625742e+03, 4.90428178e+02],
#        [0.00000000e+00, 0.00000000e+00, 1.00000000e+00]])

# %%
inv_mtx = np.linalg.inv(mtx)

# %%
inv_mtx
# Out:
# array([[ 5.16653910e-04,  0.00000000e+00, -1.72831694e-01],
#        [ 0.00000000e+00,  5.13806647e-04, -2.51985258e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]])

# %%
trapezoids[i]
# Out:
# [291, 393, 175, 599, 279, 419]

# %%
point=[300,300,1]

# %%
#depth_from_videoで深度情報を獲得

# %%
depth=4

# %%
depth*np.dot(inv_mtx,point)
#座標が決まる
# Out:
# array([-0.07134208, -0.39137305,  4.        ])

# %% [markdown]
# # depthをちゃんと求めよう

# %%
# %run -i  inference.py --logtostderr --file_extension jpg --depth --egomotion false --input_dir input --output_dir output --model_ckpt cityscapes_kitti_learned_intrinsics/model-1000977
# Out:
# I0115 15:41:18.218232 140735946695552 model.py:107] data_dir: None
# I0115 15:41:18.219308 140735946695552 model.py:108] file_extension: png
# I0115 15:41:18.220244 140735946695552 model.py:109] is_training: False
# I0115 15:41:18.222339 140735946695552 model.py:110] learning_rate: 0.0002
# I0115 15:41:18.226953 140735946695552 model.py:111] reconstr_weight: 0.85
# I0115 15:41:18.228356 140735946695552 model.py:112] smooth_weight: 0.05
# I0115 15:41:18.230498 140735946695552 model.py:113] ssim_weight: 0.15
# I0115 15:41:18.231265 140735946695552 model.py:114] icp_weight: 0.0
# I0115 15:41:18.232252 140735946695552 model.py:115] size_constraint_weight: 0.0
# I0115 15:41:18.234393 140735946695552 model.py:116] beta1: 0.9
# I0115 15:41:18.235584 140735946695552 model.py:117] batch_size: 1
# I0115 15:41:18.237857 140735946695552 model.py:118] img_height: 128
# I0115 15:41:18.238836 140735946695552 model.py:119] img_width: 416
# I0115 15:41:18.240323 140735946695552 model.py:120] seq_length: 3
# I0115 15:41:18.241868 140735946695552 model.py:121] architecture: resnet
# I0115 15:41:18.243377 140735946695552 model.py:122] imagenet_norm: True
# I0115 15:41:18.245277 140735946695552 model.py:123] weight_reg: 0.05
# I0115 15:41:18.246277 140735946695552 model.py:124] exhaustive_mode: False
# I0115 15:41:18.247235 140735946695552 model.py:125] random_scale_crop: False
# I0115 15:41:18.248721 140735946695552 model.py:126] flipping_mode: random
# I0115 15:41:18.249689 140735946695552 model.py:127] random_color: True
# I0115 15:41:18.252015 140735946695552 model.py:128] depth_upsampling: True
# I0115 15:41:18.253787 140735946695552 model.py:129] depth_normalization: True
# I0115 15:41:18.254661 140735946695552 model.py:130] compute_minimum_loss: True
# I0115 15:41:18.256816 140735946695552 model.py:131] use_skip: True
# I0115 15:41:18.257839 140735946695552 model.py:132] joint_encoder: False
# I0115 15:41:18.259042 140735946695552 model.py:133] build_sum: True
# I0115 15:41:18.261265 140735946695552 model.py:134] shuffle: True
# I0115 15:41:18.262387 140735946695552 model.py:135] input_file: train
# I0115 15:41:18.263870 140735946695552 model.py:136] handle_motion: False
# I0115 15:41:18.265423 140735946695552 model.py:137] equal_weighting: False
# I0115 15:41:18.266737 140735946695552 model.py:138] train_global_scale_var: True
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# W0115 15:41:18.273674 140735946695552 deprecation.py:323] From /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/gosato/Desktop/sekilab_3A2/models/research/struct2depth/nets.py:503: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.batch_normalization instead.
# W0115 15:41:18.309136 140735946695552 deprecation.py:323] From /Users/gosato/Desktop/sekilab_3A2/models/research/struct2depth/nets.py:503: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.batch_normalization instead.
# I0115 15:41:19.984463 140735946695552 util.py:150] Model Parameters:
# I0115 15:41:19.992073 140735946695552 util.py:155] depth_prediction/conv1/bn/beta (64,): 64
# I0115 15:41:19.993504 140735946695552 util.py:155] depth_prediction/conv1/bn/gamma (64,): 64
# I0115 15:41:19.996155 140735946695552 util.py:155] depth_prediction/conv1/bn/moving_mean (64,): 64
# I0115 15:41:19.998298 140735946695552 util.py:155] depth_prediction/conv1/bn/moving_variance (64,): 64
# I0115 15:41:20.000179 140735946695552 util.py:155] depth_prediction/conv1/conv/kernel (7, 7, 3, 64): 9,408
# I0115 15:41:20.002099 140735946695552 util.py:155] depth_prediction/conv2_1/bn_1/beta (64,): 64
# I0115 15:41:20.005467 140735946695552 util.py:155] depth_prediction/conv2_1/bn_1/gamma (64,): 64
# W0115 15:41:20.337336 140735946695552 util.py:200] Did not find var depth_prediction/disp3/weights in checkpoint: model-1000977
# W0115 15:41:20.338778 140735946695552 util.py:200] Did not find var depth_prediction/disp4/biases in checkpoint: model-1000977
# W0115 15:41:20.341032 140735946695552 util.py:200] Did not find var depth_prediction/disp4/weights in checkpoint: model-1000977
# W0115 15:41:20.344079 140735946695552 util.py:200] Did not find var egomotion_prediction/pose_exp_net/cnv1/biases in checkpoint: model-1000977
# W0115 15:41:20.345036 140735946695552 util.py:200] Did not find var egomotion_prediction/pose_exp_net/cnv1/weights in checkpoint: model-1000977
# W0115 15:41:20.346782 140735946695552 util.py:200] Did not find var egomotion_prediction/pose_exp_net/cnv2/biases in checkpoint: model-1000977
# W0115 15:41:20.348806 140735946695552 util.py:200] Did not find var egomotion_prediction/pose_exp_net/cnv2/weights in checkpoint: model-1000977
# W0115 15:41:20.350125 140735946695552 util.py:200] Did not find var egomotion_prediction/pose_exp_net/cnv3/biases in checkpoint: model-1000977
# W0115 15:41:20.350952 140735946695552 util.py:200] Did not find var egomotion_prediction/pose_exp_net/cnv3/weights in checkpoint: model-1000977
# W0115 15:41:20.352614 140735946695552 util.py:200] Did not find var egomotion_prediction/pose_exp_net/cnv4/biases in checkpoint: model-1000977
# W0115 15:41:20.353499 140735946695552 util.py:200] Did not find var egomotion_prediction/pose_exp_net/cnv4/weights in checkpoint: model-1000977
# W0115 15:41:20.355381 140735946695552 util.py:200] Did not find var egomotion_prediction/pose_exp_net/cnv5/biases in checkpoint: model-1000977
# W0115 15:41:20.357415 140735946695552 util.py:200] Did not find var egomotion_prediction/pose_exp_net/cnv5/weights in checkpoint: model-1000977
# W0115 15:41:20.358876 140735946695552 util.py:200] Did not find var egomotion_prediction/pose_exp_net/pose/cnv6/biases in checkpoint: model-1000977
# W0115 15:41:20.360023 140735946695552 util.py:200] Did not find var egomotion_prediction/pose_exp_net/pose/cnv6/weights in checkpoint: model-1000977
# W0115 15:41:20.361733 140735946695552 util.py:200] Did not find var egomotion_prediction/pose_exp_net/pose/cnv7/biases in checkpoint: model-1000977
# W0115 15:41:20.362740 140735946695552 util.py:200] Did not find var egomotion_prediction/pose_exp_net/pose/cnv7/weights in checkpoint: model-1000977
# W0115 15:41:20.364887 140735946695552 util.py:200] Did not find var egomotion_prediction/pose_exp_net/pose/pred/biases in checkpoint: model-1000977
# W0115 15:41:20.365829 140735946695552 util.py:200] Did not find var egomotion_prediction/pose_exp_net/pose/pred/weights in checkpoint: model-1000977
# W0115 15:41:20.367590 140735946695552 util.py:200] Did not find var global_scale_var in checkpoint: model-1000977
# W0115 15:41:20.368652 140735946695552 util.py:210] The following variables in the checkpoint were not loaded:
# I0115 15:41:20.370034 140735946695552 util.py:212] MotionFieldNet/CameraIntrinsics/foci/biases
# I0115 15:41:20.372858 140735946695552 util.py:212] MotionFieldNet/CameraIntrinsics/foci/weights
# I0115 15:41:20.373929 140735946695552 util.py:212] MotionFieldNet/CameraIntrinsics/offsets/weights
# I0115 15:41:20.376013 140735946695552 util.py:212] MotionFieldNet/Conv/biases
# I0115 15:41:20.378928 140735946695552 util.py:212] MotionFieldNet/Conv/weights
# I0115 15:41:20.381691 140735946695552 util.py:212] MotionFieldNet/Conv1/biases
# I0115 15:41:20.382993 140735946695552 util.py:212] MotionFieldNet/Conv1/weights
# I0115 15:41:20.384503 140735946695552 util.py:212] MotionFieldNet/Conv2/biases
# I0115 15:41:20.386240 140735946695552 util.py:212] MotionFieldNet/Conv2/weights
# I0115 15:41:20.390013 140735946695552 util.py:212] MotionFieldNet/Conv3/biases
# I0115 15:41:20.390947 140735946695552 util.py:212] MotionFieldNet/Conv3/weights
# I0115 15:41:20.393651 140735946695552 util.py:212] MotionFieldNet/Conv4/biases
# I0115 15:41:20.395421 140735946695552 util.py:212] MotionFieldNet/Conv4/weights
# I0115 15:41:20.398202 140735946695552 util.py:212] MotionFieldNet/Conv5/biases
# I0115 15:41:20.399250 140735946695552 util.py:212] MotionFieldNet/Conv5/weights
# I0115 15:41:20.451079 140735946695552 util.py:212] MotionFieldNet/Conv_3/biases
# I0115 15:41:20.452428 140735946695552 util.py:212] MotionFieldNet/Conv_3/weights
# I0115 15:41:20.453695 140735946695552 util.py:212] MotionFieldNet/Conv_4/biases
# I0115 15:41:20.454814 140735946695552 util.py:212] MotionFieldNet/Conv_4/weights
# I0115 15:41:20.455883 140735946695552 util.py:212] MotionFieldNet/Conv_5/biases
# I0115 15:41:20.456799 140735946695552 util.py:212] MotionFieldNet/Conv_5/weights
# I0115 15:41:20.457893 140735946695552 util.py:212] MotionFieldNet/Conv_6/biases
# I0115 15:41:20.458671 140735946695552 util.py:212] MotionFieldNet/Conv_6/weights
# I0115 15:41:20.459779 140735946695552 util.py:212] MotionFieldNet/Conv_7/biases
# I0115 15:41:20.461195 140735946695552 util.py:212] MotionFieldNet/Conv_7/weights
# I0115 15:41:20.462103 140735946695552 util.py:212] MotionFieldNet/Conv_8/biases
# I0115 15:41:20.463567 140735946695552 util.py:212] MotionFieldNet/Conv_8/weights
# I0115 15:41:20.464655 140735946695552 util.py:212] MotionFieldNet/Conv_9/biases
# I0115 15:41:20.465941 140735946695552 util.py:212] MotionFieldNet/Conv_9/weights
# I0115 15:41:20.466905 140735946695552 util.py:212] MotionFieldNet/Scales/rotation
# I0115 15:41:20.468327 140735946695552 util.py:212] MotionFieldNet/Scales/translation
# I0115 15:41:20.470490 140735946695552 util.py:212] MotionFieldNet/background_motion/weights
# I0115 15:41:20.477573 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet/Conv1/Relu/MotionBottleneck/weights
# I0115 15:41:20.478552 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet/Conv2/Relu/MotionBottleneck/weights
# I0115 15:41:20.479515 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet/Conv3/Relu/MotionBottleneck/weights
# I0115 15:41:20.480826 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet/Conv4/Relu/MotionBottleneck/weights
# I0115 15:41:20.481927 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet/Conv5/Relu/MotionBottleneck/weights
# I0115 15:41:20.483203 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet/Conv6/Relu/MotionBottleneck/weights
# I0115 15:41:20.484618 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet/Conv7/Relu/MotionBottleneck/weights
# I0115 15:41:20.485956 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet_1/Conv1/Relu/MotionBottleneck/weights
# I0115 15:41:20.487161 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet_1/Conv2/Relu/MotionBottleneck/weights
# I0115 15:41:20.488383 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet_1/Conv3/Relu/MotionBottleneck/weights
# I0115 15:41:20.489442 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet_1/Conv4/Relu/MotionBottleneck/weights
# I0115 15:41:20.490453 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet_1/Conv5/Relu/MotionBottleneck/weights
# I0115 15:41:20.491518 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet_1/Conv6/Relu/MotionBottleneck/weights
# I0115 15:41:20.492785 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet_1/Conv7/Relu/MotionBottleneck/weights
# I0115 15:41:20.493789 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet_2/Conv1/Relu/MotionBottleneck/weights
# I0115 15:41:20.494934 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet_2/Conv2/Relu/MotionBottleneck/weights
# I0115 15:41:20.495965 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet_2/Conv3/Relu/MotionBottleneck/weights
# I0115 15:41:20.496951 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet_2/Conv4/Relu/MotionBottleneck/weights
# I0115 15:41:20.498031 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet_2/Conv5/Relu/MotionBottleneck/weights
# I0115 15:41:20.499444 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet_2/Conv6/Relu/MotionBottleneck/weights
# I0115 15:41:20.500591 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet_2/Conv7/Relu/MotionBottleneck/weights
# I0115 15:41:20.502059 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet_3/Conv1/Relu/MotionBottleneck/weights
# I0115 15:41:20.503705 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet_3/Conv2/Relu/MotionBottleneck/weights
# I0115 15:41:20.507503 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet_3/Conv3/Relu/MotionBottleneck/weights
# I0115 15:41:20.508660 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet_3/Conv4/Relu/MotionBottleneck/weights
# I0115 15:41:20.509855 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet_3/Conv5/Relu/MotionBottleneck/weights
# I0115 15:41:20.511045 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet_3/Conv6/Relu/MotionBottleneck/weights
# I0115 15:41:20.514683 140735946695552 util.py:212] MotionFieldNet/compute_loss/MotionFieldNet_3/Conv7/Relu/MotionBottleneck/weights
# I0115 15:41:20.515753 140735946695552 util.py:212] MotionFieldNet/compute_loss/concat/MotionBottleneck/weights
# I0115 15:41:20.516865 140735946695552 util.py:212] MotionFieldNet/compute_loss/concat_1/MotionBottleneck/weights
# I0115 15:41:20.521470 140735946695552 util.py:212] MotionFieldNet/compute_loss/concat_10/MotionBottleneck/weights
# I0115 15:41:20.523030 140735946695552 util.py:212] MotionFieldNet/compute_loss/concat_11/MotionBottleneck/weights
# I0115 15:41:20.524176 140735946695552 util.py:212] global_step
# WARNING:tensorflow:From /Users/gosato/Desktop/sekilab_3A2/models/research/struct2depth/inference.py:160: Supervisor.__init__ (from tensorflow.python.training.supervisor) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.MonitoredTrainingSession
# W0115 15:41:20.766298 140735946695552 deprecation.py:323] From /Users/gosato/Desktop/sekilab_3A2/models/research/struct2depth/inference.py:160: Supervisor.__init__ (from tensorflow.python.training.supervisor) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.MonitoredTrainingSession
# INFO:tensorflow:Running local_init_op.
# I0115 15:41:21.943781 140735946695552 session_manager.py:491] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I0115 15:41:21.983495 140735946695552 session_manager.py:493] Done running local_init_op.
# INFO:tensorflow:Starting standard services.
# I0115 15:41:22.975403 140735946695552 supervisor.py:733] Starting standard services.
# INFO:tensorflow:Starting queue runners.
# I0115 15:41:22.984467 140735946695552 supervisor.py:740] Starting queue runners.
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# W0115 15:41:22.988085 140735946695552 deprecation.py:323] From /anaconda3/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from cityscapes_kitti_learned_intrinsics/model-1000977
# I0115 15:41:22.991652 140735946695552 saver.py:1270] Restoring parameters from cityscapes_kitti_learned_intrinsics/model-1000977
# I0115 15:41:23.256222 140735946695552 inference.py:165] Predictions will be saved in output.
# I0115 15:41:23.257697 140735946695552 inference.py:173] Running inference on 7 files.
# I0115 15:41:23.259804 140735946695552 inference.py:183] 0 of 7 files processed.
# I0115 15:41:26.347310 140735946695552 inference.py:247] Writing egomotion sequence to output/./egomotion.txt.
# I0115 15:41:26.649472 140735946695552 inference.py:318] Done.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/Desktop/sekilab_3A2/models/research/struct2depth/inference.py in <module>
# ----> 1 get_ipython().run_line_magic('run', '-i  inference.py --logtostderr --file_extension jpg --depth --egomotion false --input_dir input --output_dir output --model_ckpt cityscapes_kitti_learned_intrinsics/model-1000977')
#
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2305                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2306             with self.builtin_trap:
# -> 2307                 result = fn(*args, **kwargs)
#    2308             return result
#    2309
#
# </anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-59> in run(self, parameter_s, runner, file_finder)
#
# /anaconda3/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /anaconda3/lib/python3.7/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     817                     else:
#     818                         # regular execution
# --> 819                         run()
#     820
#     821             if 'i' in opts:
#
# /anaconda3/lib/python3.7/site-packages/IPython/core/magics/execution.py in run()
#     803                         def run():
#     804                             runner(filename, prog_ns, prog_ns,
# --> 805                                     exit_ignore=exit_ignore)
#     806
#     807                     if 't' in opts:
#
# /anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py in mpl_execfile(fname, *where, **kw)
#     178         matplotlib.interactive(is_interactive)
#     179         # make rendering call now, if the user tried to do it
# --> 180         if plt.draw_if_interactive.called:
#     181             plt.draw()
#     182             plt.draw_if_interactive.called = False
#
# AttributeError: 'function' object has no attribute 'called'

# %% [markdown]
# # 以下はxmlファイルがないと実行不可

# %%
def search_point_grid(trapezoid,x_split,y_split,search_x,search_y):
    
    x_top_left=trapezoid[0]
    x_top_right=trapezoid[1]
    x_bottom_left=trapezoid[2]
    x_bottom_right=trapezoid[3]
    y_top=trapezoid[4]
    y_bottom=trapezoid[5]
    
    #(search_x,search_y)が台形のどの分割グリッドにあるか求める
    #分割グリッドは左上から((0,0),(1,0)...(x_split-1,0)),(0,1),(1,1),...,(x_split-1,1)),...,((0,y_split-1),(1,y_split-1),...,(x_split-1,y_split-1))と並ぶ
    
    #y_resultとして許される最大値はy_split-1
    result_y_max=y_split-1
    #グリッドのyの値を初期値0に設定
    result_y=0
    while result_y<=result_y_max:
        #現在のy_resultについてグリッドのy座標を決定する
        grid_top_y=y_top+(y_bottom-y_top)*((result_y)/y_split)
        grid_bottom_y=y_top+(y_bottom-y_top)*((result_y+1)/y_split)
        if grid_top_y<=search_y<grid_bottom_y:
            break
        else:
            result_y+=1
        if result_y>result_y_max:
            #print("y is out of the trapezoid.")
            return(None)
        else:
            pass

    #search_yにおける台形の左端,右端のx座標を求める
    x_left=x_top_left+(x_bottom_left-x_top_left)*(search_y-y_top)/(y_bottom-y_top)
    x_right=x_top_right+(x_bottom_right-x_top_right)*(search_y-y_top)/(y_bottom-y_top)
    result_x=0
    result_x_max=x_split-1
    while result_x<=result_x_max:
        grid_left_x=x_left+(x_right-x_left)*((result_x)/x_split)
        grid_right_x=x_left+(x_right-x_left)*((result_x+1)/x_split)
        if grid_left_x<=search_x<grid_right_x:
            break
        else:
            result_x+=1
        if result_x>result_x_max:
            #print("x is out of the trapezoid.")
            return(None)
        else:
            pass
    result_grid=(result_x,result_y)
    return result_grid

# %%
def crack_ratio_calculate(trapezoid,boundingboxes,x_split,y_split):
    
    result_D00_D10=[]
    #重率0.6
    result_D20=[]
    #重率1
        
    for i in range(0,len(boundingboxes)):
        
        xmin=boundingboxes[i][0]
        xmax=boundingboxes[i][1]
        ymin=boundingboxes[i][2]
        ymax=boundingboxes[i][3]
        class_of_damage=boundingboxes[i][4]
        
        x_temp=xmin
        y_temp=ymin
        
        result_D00_D10_temp=[]
        result_D20_temp=[]
        
        if class_of_damage=="D00":

            while y_temp<=ymax:
                while x_temp<=xmax:
                    grid_temp=search_point_grid(trapezoid,x_split,y_split,x_temp,y_temp)
                    if grid_temp==None:
                        pass
                    elif grid_temp in result_D00_D10_temp:
                        pass
                    else:
                        result_D00_D10_temp.append(grid_temp)
                    x_temp+=1
                y_temp+=1
                x_temp=xmin
        elif class_of_damage=="D10":

            while y_temp<=ymax:
                while x_temp<=xmax:
                    grid_temp=search_point_grid(trapezoid,x_split,y_split,x_temp,y_temp)
                    if grid_temp==None:
                        pass
                    elif grid_temp in result_D00_D10_temp:
                        pass
                    else:
                        result_D00_D10_temp.append(grid_temp)
                    x_temp+=1
                y_temp+=1
                x_temp=xmin
        elif class_of_damage=="D20":

            while y_temp<=ymax:
                while x_temp<=xmax:
                    grid_temp=search_point_grid(trapezoid,x_split,y_split,x_temp,y_temp)
                    if grid_temp==None:
                        pass
                    elif grid_temp in result_D20_temp:
                        pass
                    else:
                        result_D20_temp.append(grid_temp)
                    x_temp+=1
                y_temp+=1
                x_temp=xmin
        else:
            pass
        
        for j in range(0,len(result_D00_D10_temp)):
            grid_temp_2=result_D00_D10_temp[j]
            
            if grid_temp_2 in result_D20:
                pass
            elif grid_temp_2 in result_D00_D10:
                result_D20.append(grid_temp_2)
                result_D00_D10.remove(grid_temp_2)
            else:
                result_D00_D10.append(grid_temp_2)
        
        for k in range(0,len(result_D20_temp)):
            grid_temp_3=result_D20_temp[k]
            if grid_temp_3 in result_D20:
                pass
            elif grid_temp_3 in result_D00_D10:
                result_D20.append(grid_temp_3)
                result_D00_D10.remove(grid_temp_3)
            else:
                result_D20.append(grid_temp_3)
    
    print("重率0.6のグリッドは"+str(result_D00_D10)+"の"+str(len(result_D00_D10))+"箇所です")
    print("重率1のグリッドは"+str(result_D20)+"の"+str(len(result_D20))+"箇所です")
    crack_ratio=(0.6*len(result_D00_D10)+len(result_D20))/(x_split*y_split)
    return crack_ratio

# %%
def boundingboxes(i):
    
    img = cv2.imread(base_path + "/images/" + file_names[i].split('.')[0] + '.jpg')
    infile_xml = open(base_path  +'/annotations/xmls/' + file_names[i].split('.')[0] + '.xml')
   

    tree = ElementTree.parse(infile_xml)
    root = tree.getroot()
    
    boundingboxes=[]
    
    for obj in root.iter('object'):
        cls_name = obj.find('name').text
        xmlbox = obj.find('bndbox')
        xmin = int(xmlbox.find('xmin').text)
        xmax = int(xmlbox.find('xmax').text)
        ymin = int(xmlbox.find('ymin').text)
        ymax = int(xmlbox.find('ymax').text)
        boundingboxes.append([xmin,xmax,ymin,ymax,cls_name])
    
    return boundingboxes

# %%
def crack_ratio(trapezoids,i,x_split,y_split):
    
    temp=boundingboxes(i)
    trapezoid=trapezoids[i]
    
    crack_ratio=crack_ratio_calculate(trapezoid,temp,x_split,y_split)
    
    return crack_ratio

# %%
def draw_images_2(trapezoids,x_split,y_split,i):
    #台形に加え、傷の位置、種類も表示するコード
    
    trapezoid=trapezoids[i]
    
    img = cv2.imread(base_path + "/images/" + file_names[i].split('.')[0] + '.jpg')
                      
    x_top_left=trapezoid[0]
    x_top_right=trapezoid[1]
    x_bottom_left=trapezoid[2]
    x_bottom_right=trapezoid[3]
    y_top=trapezoid[4]
    y_bottom=trapezoid[5]
    
    pts = np.array([[x_top_left,y_top],[x_bottom_left,y_bottom],[x_bottom_right,y_bottom],[x_top_right,y_top]])
    
    cv2.polylines(img,[pts],True,(0,255,255),2)
    
    pts2=[]
    
    #grid_xとして許される最大値はx_split-1
    grid_x_max=x_split-1
    #グリッドのxの値を初期値1に設定
    grid_x=1
    
    while grid_x<=grid_x_max:
        #現在のgrid_xについてグリッド上下端の座標を決定する
        x_top_line=int(x_top_left+(x_top_right-x_top_left)*(grid_x/x_split))
        x_bottom_line=int(x_bottom_left+(x_bottom_right-x_bottom_left)*(grid_x/x_split))
        pts2.append([[x_top_line,y_top],[x_bottom_line,y_bottom]])
        grid_x+=1
 
    grid_y_max=y_split-1
    grid_y=1
    
    while grid_y<=grid_y_max:
        
        x_left_line=int(x_top_left+(x_bottom_left-x_top_left)*(grid_y/y_split))
        x_right_line=int(x_top_right+(x_bottom_right-x_top_right)*(grid_y/y_split))
        y_line=int(y_top+(y_bottom-y_top)*(grid_y/y_split))
        pts2.append([[x_left_line,y_line],[x_right_line,y_line]])
        grid_y+=1
    
    for line in pts2:
        
        line=np.array(line)
        cv2.polylines(img,[line],True,(0,255,255),2)
    
    #ここをどうするか？
    
    
    infile_xml = open(base_path  +'/annotations/xmls/' + file_names[i].split('.')[0] + '.xml')
    tree = ElementTree.parse(infile_xml)
    root = tree.getroot()
    
    for obj in root.iter('object'):
        cls_name = obj.find('name').text
        xmlbox = obj.find('bndbox')
        xmin = int(xmlbox.find('xmin').text)
        xmax = int(xmlbox.find('xmax').text)
        ymin = int(xmlbox.find('ymin').text)
        ymax = int(xmlbox.find('ymax').text)

        font = cv2.FONT_HERSHEY_SIMPLEX

        # put text
        cv2.putText(img,cls_name,(xmin,ymin-10),font,1,(0,255,0),2,cv2.LINE_AA)

        # draw bounding box
        cv2.rectangle(img, (xmin, ymin), (xmax, ymax), (0,255,0),3)
                      

    
    
    return img

# %%
i=45

#i=52

print("ひび割れ率は"+str(crack_ratio(trapezoids,i,x_split,y_split))+"です")  
 
fig=plt.figure(figsize=(6,6))
img = draw_images_2(trapezoids,x_split,y_split,i)
plt.axis('on')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# Out:
# 重率0.6のグリッドは[(0, 2), (1, 2), (0, 3), (1, 3), (0, 4), (1, 4), (2, 4), (0, 5), (1, 5), (2, 5), (0, 6), (1, 6), (2, 6), (3, 6), (0, 7), (1, 7), (2, 7), (3, 7), (0, 8), (1, 8), (2, 8), (3, 8), (0, 9), (1, 9), (2, 9), (3, 9)]の26箇所です
# 重率1のグリッドは[(6, 2), (7, 2), (8, 2), (9, 2), (6, 3), (7, 3), (8, 3), (9, 3), (6, 4), (7, 4), (8, 4), (9, 4), (5, 4), (5, 5), (6, 5), (7, 5), (8, 5), (9, 5), (5, 6), (6, 6), (7, 6), (8, 6), (9, 6), (5, 7), (6, 7), (7, 7), (8, 7), (9, 7), (5, 8), (6, 8), (7, 8), (8, 8), (9, 8), (5, 9), (6, 9), (7, 9), (8, 9), (9, 9)]の38箇所です
# ひび割れ率は0.536です

# %% [markdown]
# # 出力

# %%
for i in range(0,len(file_names)):


    img = draw_images_2(trapezoids,x_split,y_split,i)




    cv2.imwrite("output_"+str(i)+".jpg", img)

# %% [markdown]
# # 以下はおまけ(実運用では不使用)

# %% [markdown]
# ## 曲線検出

# %%
i=32
image_file=base_path + "/images/" + file_names[i]

img = cv2.imread(image_file)
#img=cv2.resize(img,(600,600))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


plt.imshow(img)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

cv2.imwrite("gray.jpg", gray)
img_p = cv2.imread('gray.jpg')
img_p2 = img[:,:,::-1]
plt.figure(figsize=(5, 5))
plt.xticks([]), plt.yticks([]) 
plt.imshow(img_p)

# %%
edges = cv2.Canny(gray,300,500,apertureSize = 3)


cv2.imwrite("edges.jpg", edges)
img_p = cv2.imread('edges.jpg')
img_p2 = img[:,:,::-1]
plt.figure(figsize=(5, 5))
plt.xticks([]), plt.yticks([]) 
plt.imshow(img_p)

# %%
def edges_in_road(edges,i,seg_maps=seg_maps):
    seg_map=seg_maps[i]
    for y in range(0,len(edges)):
         for x in range(0,len(edges[0])):
                if check_in_road(x,y,seg_map):
                    pass
                else:
                    edges[y][x]=0
    return edges

# %%
edges = cv2.Canny(gray,300,500,apertureSize = 3)
#print(edges)
edges = edges_in_road(edges,i)
#print(edges[400])

cv2.imwrite("edges.jpg", edges)
img_p = cv2.imread('edges.jpg')
img_p2 = img[:,:,::-1]
plt.figure(figsize=(5, 5))
plt.xticks([]), plt.yticks([]) 
plt.imshow(img_p)

# %%
def edges_left_line(edges,i, left_lines=left_lines,width=50):
    #600*600の画像が前提
    x1, y1, x2, y2 = left_lines[i][0]
    #print(y1)
    line_binary = np.zeros_like(edges)
    
    for y in range(max(0,y2-width),min(599,y1+width)):
        x_temp=int(x1+(x2-x1)*((y1-y)/(y1-y2)))
        #print(x_temp)
        for x in range(max(0,x_temp-width),min(599,x_temp+width)):
            #print(x)
            line_binary[y][x]=255
    
    #for x in range(0,100):
        #for y in range(0,100):
            #line_binary[y][x]=1
    #result=line_binary
    
    result=np.zeros_like(edges)
    result[(line_binary == 255) & (edges == 255)]=255
    return result

# %%
def get_fitting_data(edges):
    result_x=[]
    result_y=[]
    for x in range(0,600):
        for y in range(0,600):
            if edges[y][x]==255:
                result_x.append(x)
                result_y.append(y)
    return [result_x,result_y]

# %%
edges = cv2.Canny(gray,300,500,apertureSize = 3)
edges = edges_in_road(edges,i)
edges = edges_left_line(edges,i)

left_point=get_fitting_data(edges)

cv2.imwrite("edges.jpg", edges)
img_p = cv2.imread('edges.jpg')
img_p2 = img[:,:,::-1]
plt.figure(figsize=(5, 5))
plt.xticks([]), plt.yticks([]) 
plt.imshow(img_p)

# %%
def edges_right_line(edges,i, right_lines=right_lines,width=50):
    #600*600の画像が前提
    #widthは大きい方がよい。100以下で設定する
    x3, y3, x4, y4 = right_lines[i][0]
    #print(y1)
    line_binary = np.zeros_like(edges)
    
    for y in range(max(0,y3-width),min(599,y4+width)):
        x_temp=int(x3+(x4-x3)*((y-y3)/(y4-y3)))
        #print(x_temp)
        for x in range(max(0,x_temp-width),min(599,x_temp+width)):
            #print(x)
            line_binary[y][x]=255
    
    #for x in range(0,100):
        #for y in range(0,100):
            #line_binary[y][x]=1
    #result=line_binary
    
    result=np.zeros_like(edges)
    result[(line_binary == 255) & (edges == 255)]=255
    return result

# %%
edges = cv2.Canny(gray,300,500,apertureSize = 3)
edges = edges_in_road(edges,i)
edges = edges_right_line(edges,i)

right_point=get_fitting_data(edges)

cv2.imwrite("edges.jpg", edges)
img_p = cv2.imread('edges.jpg')
img_p2 = img[:,:,::-1]
plt.figure(figsize=(5, 5))
plt.xticks([]), plt.yticks([]) 
plt.imshow(img_p)

# %%
right_point
# Out:
# [[351,
#   351,
#   351,
#   351,
#   352,
#   352,
#   352,
#   352,
#   352,
#   352,
#   352,
#   352,
#   353,
#   353,
#   353,
#   354,
#   354,
#   354,
#   354,
#   354,
#   355,
#   355,
#   355,
#   355,
#   356,
#   356,
#   356,
#   356,
#   356,
#   357,
#   357,
#   357,
#   357,
#   357,
#   357,
#   358,
#   358,
#   358,
#   358,
#   359,
#   359,
#   359,
#   359,
#   360,
#   360,
#   360,
#   360,
#   360,
#   360,
#   361,
#   361,
#   361,
#   361,
#   361,
#   361,
#   361,
#   361,
#   362,
#   362,
#   362,
#   362,
#   362,
#   362,
#   363,
#   363,
#   363,
#   363,
#   363,
#   363,
#   363,
#   363,
#   364,
#   364,
#   365,
#   365,
#   365,
#   365,
#   365,
#   366,
#   366,
#   366,
#   366,
#   366,
#   366,
#   367,
#   367,
#   367,
#   368,
#   368,
#   368,
#   368,
#   368,
#   368,
#   369,
#   369,
#   369,
#   369,
#   370,
#   370,
#   370,
#   370,
#   370,
#   371,
#   371,
#   371,
#   371,
#   371,
#   372,
#   372,
#   372,
#   372,
#   372,
#   373,
#   373,
#   373,
#   373,
#   374,
#   374,
#   374,
#   374,
#   374,
#   375,
#   375,
#   375,
#   375,
#   376,
#   376,
#   376,
#   376,
#   376,
#   377,
#   377,
#   377,
#   377,
#   377,
#   378,
#   378,
#   378,
#   378,
#   378,
#   379,
#   379,
#   379,
#   379,
#   379,
#   379,
#   379,
#   380,
#   380,
#   380,
#   381,
#   381,
#   381,
#   381,
#   381,
#   382,
#   382,
#   382,
#   382,
#   382,
#   383,
#   383,
#   383,
#   383,
#   384,
#   384,
#   384,
#   384,
#   385,
#   385,
#   385,
#   385,
#   386,
#   386,
#   386,
#   386,
#   386,
#   386,
#   386,
#   386,
#   387,
#   387,
#   387,
#   388,
#   389,
#   389,
#   390,
#   390,
#   390,
#   391,
#   391,
#   391,
#   391,
#   392,
#   392,
#   392,
#   392,
#   393,
#   393,
#   393,
#   393,
#   393,
#   394,
#   394,
#   394,
#   394,
#   394,
#   395,
#   395,
#   395,
#   395,
#   396,
#   396,
#   396,
#   396,
#   396,
#   396,
#   396,
#   396,
#   397,
#   397,
#   397,
#   397,
#   397,
#   398,
#   398,
#   398,
#   398,
#   398,
#   399,
#   399,
#   399,
#   399,
#   399,
#   399,
#   399,
#   399,
#   400,
#   400,
#   400,
#   400,
#   401,
#   401,
#   401,
#   401,
#   401,
#   401,
#   401,
#   401,
#   402,
#   402,
#   402,
#   402,
#   403,
#   403,
#   403,
#   403,
#   404,
#   404,
#   404,
#   404,
#   404,
#   405,
#   405,
#   405,
#   405,
#   405,
#   405,
#   406,
#   406,
#   406,
#   406,
#   406,
#   406,
#   406,
#   407,
#   407,
#   407,
#   407,
#   407,
#   407,
#   407,
#   408,
#   408,
#   408,
#   408,
#   409,
#   409,
#   409,
#   409,
#   409,
#   409,
#   410,
#   410,
#   410,
#   410,
#   410,
#   411,
#   411,
#   412,
#   412,
#   412,
#   412,
#   412,
#   412,
#   412,
#   412,
#   412,
#   413,
#   413,
#   413,
#   413,
#   414,
#   414,
#   414,
#   414,
#   414,
#   414,
#   414,
#   414,
#   415,
#   415,
#   415,
#   415,
#   415,
#   415,
#   415,
#   416,
#   416,
#   416,
#   416,
#   416,
#   416,
#   416,
#   417,
#   417,
#   417,
#   417,
#   417,
#   417,
#   418,
#   418,
#   418,
#   419,
#   419,
#   419,
#   420,
#   420,
#   420,
#   420,
#   420,
#   420,
#   421,
#   421,
#   421,
#   421,
#   422,
#   422,
#   422,
#   422,
#   423,
#   423,
#   423,
#   423,
#   423,
#   423,
#   424,
#   424,
#   424,
#   424,
#   424,
#   424,
#   424,
#   424,
#   424,
#   425,
#   425,
#   425,
#   425,
#   425,
#   426,
#   426,
#   426,
#   426,
#   426,
#   426,
#   427,
#   427,
#   427,
#   427,
#   427,
#   427,
#   427,
#   428,
#   428,
#   428,
#   428,
#   428,
#   429,
#   429,
#   429,
#   429,
#   430,
#   430,
#   430,
#   431,
#   431,
#   432,
#   432,
#   433,
#   434,
#   434,
#   435,
#   435,
#   436,
#   436,
#   436,
#   436,
#   436,
#   437,
#   437,
#   437,
#   437,
#   438,
#   438,
#   438,
#   439,
#   439,
#   439,
#   439,
#   440,
#   440,
#   440,
#   441,
#   441,
#   441,
#   441,
#   442,
#   442,
#   442,
#   442,
#   442,
#   443,
#   443,
#   443,
#   443,
#   443,
#   443,
#   443,
#   444,
#   444,
#   444,
#   444,
#   444,
#   444,
#   445,
#   445,
#   445,
#   445,
#   446,
#   446,
#   446,
#   447,
#   447,
#   448,
#   448,
#   449,
#   449,
#   450,
#   450,
#   451,
#   451,
#   452,
#   453,
#   453,
#   454,
#   454,
#   454,
#   455,
#   456,
#   457,
#   457,
#   458,
#   458,
#   458,
#   459,
#   459,
#   460,
#   460,
#   460,
#   461,
#   461,
#   461,
#   462,
#   463,
#   463,
#   464,
#   464,
#   465,
#   466,
#   466,
#   467,
#   467,
#   468,
#   468,
#   469,
#   469,
#   469,
#   469,
#   470,
#   470,
#   471,
#   472,
#   473,
#   474,
#   474,
#   475,
#   475,
#   475,
#   476,
#   477,
#   477,
#   478,
#   478,
#   479,
#   480,
#   480,
#   481,
#   481,
#   482,
#   482,
#   483,
#   483,
#   484,
#   485,
#   485,
#   486,
#   486,
#   487,
#   487,
#   488,
#   488,
#   489,
#   490,
#   491,
#   492],
#  [394,
#   395,
#   396,
#   397,
#   398,
#   399,
#   400,
#   401,
#   402,
#   403,
#   404,
#   405,
#   406,
#   407,
#   408,
#   409,
#   410,
#   411,
#   432,
#   433,
#   412,
#   413,
#   433,
#   435,
#   413,
#   414,
#   415,
#   433,
#   435,
#   416,
#   417,
#   418,
#   434,
#   436,
#   437,
#   418,
#   419,
#   420,
#   435,
#   420,
#   421,
#   422,
#   435,
#   422,
#   423,
#   435,
#   439,
#   440,
#   444,
#   423,
#   424,
#   425,
#   426,
#   435,
#   441,
#   442,
#   445,
#   426,
#   427,
#   428,
#   443,
#   444,
#   447,
#   428,
#   429,
#   430,
#   444,
#   445,
#   446,
#   448,
#   449,
#   431,
#   446,
#   431,
#   432,
#   447,
#   448,
#   449,
#   432,
#   433,
#   434,
#   450,
#   451,
#   452,
#   435,
#   453,
#   455,
#   435,
#   436,
#   437,
#   453,
#   456,
#   457,
#   437,
#   438,
#   454,
#   455,
#   438,
#   439,
#   440,
#   456,
#   457,
#   441,
#   442,
#   457,
#   458,
#   459,
#   442,
#   443,
#   444,
#   459,
#   460,
#   444,
#   445,
#   460,
#   461,
#   445,
#   446,
#   447,
#   461,
#   462,
#   447,
#   448,
#   463,
#   464,
#   448,
#   449,
#   465,
#   466,
#   469,
#   449,
#   450,
#   466,
#   467,
#   470,
#   450,
#   451,
#   468,
#   471,
#   472,
#   452,
#   453,
#   454,
#   469,
#   472,
#   473,
#   474,
#   454,
#   455,
#   456,
#   456,
#   457,
#   472,
#   473,
#   476,
#   457,
#   458,
#   474,
#   477,
#   478,
#   459,
#   460,
#   475,
#   476,
#   460,
#   476,
#   477,
#   478,
#   460,
#   461,
#   478,
#   479,
#   461,
#   462,
#   463,
#   479,
#   480,
#   481,
#   482,
#   483,
#   464,
#   483,
#   484,
#   464,
#   464,
#   465,
#   465,
#   466,
#   485,
#   466,
#   467,
#   468,
#   486,
#   468,
#   469,
#   487,
#   491,
#   469,
#   470,
#   488,
#   489,
#   492,
#   470,
#   471,
#   489,
#   490,
#   493,
#   471,
#   472,
#   491,
#   494,
#   472,
#   473,
#   474,
#   475,
#   476,
#   492,
#   495,
#   496,
#   476,
#   477,
#   493,
#   496,
#   497,
#   477,
#   493,
#   494,
#   498,
#   499,
#   477,
#   478,
#   493,
#   495,
#   496,
#   499,
#   500,
#   501,
#   479,
#   480,
#   495,
#   497,
#   480,
#   481,
#   495,
#   498,
#   499,
#   500,
#   501,
#   502,
#   481,
#   482,
#   500,
#   502,
#   482,
#   483,
#   504,
#   505,
#   483,
#   484,
#   503,
#   505,
#   511,
#   484,
#   485,
#   503,
#   506,
#   507,
#   511,
#   484,
#   485,
#   486,
#   487,
#   503,
#   509,
#   511,
#   486,
#   487,
#   504,
#   505,
#   506,
#   509,
#   512,
#   488,
#   506,
#   507,
#   510,
#   488,
#   489,
#   490,
#   508,
#   512,
#   514,
#   490,
#   509,
#   510,
#   512,
#   514,
#   491,
#   510,
#   491,
#   492,
#   493,
#   494,
#   495,
#   510,
#   511,
#   513,
#   514,
#   495,
#   511,
#   519,
#   521,
#   496,
#   512,
#   513,
#   515,
#   516,
#   517,
#   519,
#   521,
#   497,
#   498,
#   513,
#   515,
#   517,
#   519,
#   522,
#   498,
#   499,
#   501,
#   517,
#   519,
#   520,
#   523,
#   499,
#   501,
#   518,
#   520,
#   521,
#   522,
#   499,
#   500,
#   518,
#   500,
#   501,
#   519,
#   502,
#   519,
#   521,
#   522,
#   523,
#   524,
#   503,
#   519,
#   521,
#   525,
#   503,
#   521,
#   525,
#   528,
#   503,
#   504,
#   525,
#   527,
#   529,
#   530,
#   504,
#   505,
#   506,
#   525,
#   527,
#   530,
#   531,
#   532,
#   533,
#   506,
#   525,
#   527,
#   533,
#   534,
#   506,
#   507,
#   525,
#   527,
#   534,
#   535,
#   507,
#   508,
#   509,
#   525,
#   527,
#   535,
#   536,
#   509,
#   510,
#   525,
#   537,
#   538,
#   511,
#   512,
#   525,
#   538,
#   512,
#   513,
#   538,
#   514,
#   515,
#   515,
#   516,
#   516,
#   516,
#   517,
#   517,
#   544,
#   517,
#   518,
#   519,
#   521,
#   544,
#   521,
#   542,
#   543,
#   545,
#   522,
#   545,
#   546,
#   522,
#   523,
#   546,
#   547,
#   523,
#   548,
#   549,
#   523,
#   524,
#   525,
#   550,
#   525,
#   526,
#   547,
#   548,
#   551,
#   527,
#   528,
#   547,
#   548,
#   549,
#   552,
#   554,
#   528,
#   529,
#   547,
#   549,
#   550,
#   555,
#   529,
#   550,
#   551,
#   555,
#   529,
#   530,
#   551,
#   530,
#   531,
#   531,
#   532,
#   533,
#   534,
#   534,
#   535,
#   535,
#   536,
#   536,
#   537,
#   539,
#   537,
#   538,
#   539,
#   540,
#   541,
#   541,
#   544,
#   541,
#   542,
#   544,
#   542,
#   544,
#   543,
#   544,
#   545,
#   545,
#   546,
#   572,
#   546,
#   546,
#   547,
#   547,
#   548,
#   548,
#   548,
#   549,
#   549,
#   550,
#   550,
#   551,
#   551,
#   552,
#   553,
#   554,
#   554,
#   555,
#   555,
#   555,
#   556,
#   556,
#   557,
#   558,
#   559,
#   560,
#   561,
#   561,
#   562,
#   562,
#   563,
#   563,
#   563,
#   564,
#   564,
#   565,
#   565,
#   566,
#   566,
#   567,
#   568,
#   568,
#   569,
#   569,
#   570,
#   570,
#   571,
#   571,
#   572,
#   572,
#   573,
#   573,
#   574]]

# %%
left_poly_line=np.polyfit(left_point[1],left_point[0],2)
right_poly_line=np.polyfit(right_point[1],right_point[0],2)

# %%
plt.plot(right_point[1], np.poly1d(np.polyfit(right_point[1],right_point[0],2))(right_point[1]), label='d=2')

# %%
np.poly1d(np.polyfit(right_point[1],right_point[0],2))(400)
# Out:
# 351.419126213526

# %%
def draw_images_3(trapezoids,x_split,y_split,i,left_poly_line,right_poly_line):
    #傷の位置、種類に加え、曲線にも対応した台形を表示するコード
    
    trapezoid=trapezoids[i]
    
    img = cv2.imread(base_path + "/images/" + file_names[i].split('.')[0] + '.jpg')
    
    y_top=trapezoid[4]
    y_bottom=trapezoid[5]
    
                      
    x_top_left=int(np.poly1d(left_poly_line)(y_top))
    x_top_right=int(np.poly1d(right_poly_line)(y_top))
    x_bottom_left=int(np.poly1d(left_poly_line)(y_bottom))
    x_bottom_right=int(np.poly1d(right_poly_line)(y_bottom))
    
    pts = np.array([[x_top_left,y_top],[x_bottom_left,y_bottom],[x_bottom_right,y_bottom],[x_top_right,y_top]])
    
    #cv2.polylines(img,[pts],True,(0,255,255),2)
    #大きな台形を生成してしまうため削除
    
    pts2=[]
    
    #grid_xとして許される最大値はx_split
    #今までと違い、グリッドは100個存在よって初期値も変わる

    #グリッドのxの値を初期値1に設定
    grid_x=0
    

    grid_y=0
    
    for grid_x in range(0,x_split):
        for grid_y in range(0,y_split):
        #現在のgrid_x,yについてグリッド上下端の座標を決定する
            y_grid_top=int(y_top+(y_bottom-y_top)*grid_y/y_split)
            y_grid_bottom=int(y_top+(y_bottom-y_top)*(grid_y+1)/y_split)
            
            x_grid_top_left=int(np.poly1d(left_poly_line)(y_grid_top)*grid_x/x_split+np.poly1d(right_poly_line)(y_grid_top)*(1-grid_x/x_split))
            x_grid_top_right=int(np.poly1d(left_poly_line)(y_grid_top)*(grid_x+1)/x_split+np.poly1d(right_poly_line)(y_grid_top)*(1-(grid_x+1)/x_split))
            x_grid_bottom_left=int(np.poly1d(left_poly_line)(y_grid_bottom)*grid_x/x_split+np.poly1d(right_poly_line)(y_grid_bottom)*(1-grid_x/x_split))
            x_grid_bottom_right=int(np.poly1d(left_poly_line)(y_grid_bottom)*(grid_x+1)/x_split+np.poly1d(right_poly_line)(y_grid_bottom)*(1-(grid_x+1)/x_split))
                                               
            grid_top_left=[x_grid_top_left,y_grid_top]
            grid_top_right=[x_grid_top_right,y_grid_top]
            grid_bottom_left=[x_grid_bottom_left,y_grid_bottom]
            grid_bottom_right=[x_grid_bottom_right,y_grid_bottom]
            
            pts2.append([grid_top_left,grid_bottom_left,grid_bottom_right,grid_top_right])
            
            
        
    
    for line in pts2:
        
        line=np.array(line)
        cv2.polylines(img,[line],True,(0,255,255),2)
    
    #ここをどうするか？
    
    
    infile_xml = open(base_path  +'/annotations/xmls/' + file_names[i].split('.')[0] + '.xml')
    tree = ElementTree.parse(infile_xml)
    root = tree.getroot()
    
    for obj in root.iter('object'):
        cls_name = obj.find('name').text
        xmlbox = obj.find('bndbox')
        xmin = int(xmlbox.find('xmin').text)
        xmax = int(xmlbox.find('xmax').text)
        ymin = int(xmlbox.find('ymin').text)
        ymax = int(xmlbox.find('ymax').text)

        font = cv2.FONT_HERSHEY_SIMPLEX

        # put text
        cv2.putText(img,cls_name,(xmin,ymin-10),font,1,(0,255,0),2,cv2.LINE_AA)

        # draw bounding box
        cv2.rectangle(img, (xmin, ymin), (xmax, ymax), (0,255,0),3)
                      

    
    
    return img

# %%
#print("ひび割れ率は"+str(crack_ratio(trapezoids,i,x_split,y_split))+"です")  
 
fig=plt.figure(figsize=(6,6))
img = draw_images_3(trapezoids,x_split,y_split,i,left_poly_line,right_poly_line)
plt.axis('on')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
def search_point_grid_2(trapezoid,x_split,y_split,search_x,search_y,left_poly_line,right_poly_line):
    
    y_top=trapezoid[4]
    y_bottom=trapezoid[5]
    x_top_left=int(np.poly1d(left_poly_line)(y_top))
    x_top_right=int(np.poly1d(right_poly_line)(y_top))
    x_bottom_left=int(np.poly1d(left_poly_line)(y_bottom))
    x_bottom_right=int(np.poly1d(right_poly_line)(y_bottom))
    
    #(search_x,search_y)が台形のどの分割グリッドにあるか求める
    #分割グリッドは左上から((0,0),(1,0)...(x_split-1,0)),(0,1),(1,1),...,(x_split-1,1)),...,((0,y_split-1),(1,y_split-1),...,(x_split-1,y_split-1))と並ぶ
    
    #y_resultとして許される最大値はy_split-1
    result_y_max=y_split-1
    #グリッドのyの値を初期値0に設定
    result_y=0
    while result_y<=result_y_max:
        #現在のy_resultについてグリッドのy座標を決定する
        grid_top_y=y_top+(y_bottom-y_top)*((result_y)/y_split)
        grid_bottom_y=y_top+(y_bottom-y_top)*((result_y+1)/y_split)
        if grid_top_y<=search_y<grid_bottom_y:
            break
        else:
            result_y+=1
        if result_y>result_y_max:
            #print("y is out of the trapezoid.")
            return(None)
        else:
            pass

    #search_yにおける台形の左端,右端のx座標を求める
    x_left=np.poly1d(left_poly_line)(search_y)
    x_right=np.poly1d(right_poly_line)(search_y)
    
    
    result_x=0
    result_x_max=x_split-1
    while result_x<=result_x_max:
        grid_left_x=x_left+(x_right-x_left)*((result_x)/x_split)
        grid_right_x=x_left+(x_right-x_left)*((result_x+1)/x_split)
        if grid_left_x<=search_x<grid_right_x:
            break
        else:
            result_x+=1
        if result_x>result_x_max:
            #print("x is out of the trapezoid.")
            return(None)
        else:
            pass
    result_grid=(result_x,result_y)
    return result_grid

# %%
def crack_ratio_calculate_2(trapezoid,boundingboxes,x_split,y_split,left_poly_line,right_poly_line):
    
    result_D00_D10=[]
    #重率0.6
    result_D20=[]
    #重率1
        
    for i in range(0,len(boundingboxes)):
        
        xmin=boundingboxes[i][0]
        xmax=boundingboxes[i][1]
        ymin=boundingboxes[i][2]
        ymax=boundingboxes[i][3]
        class_of_damage=boundingboxes[i][4]
        
        x_temp=xmin
        y_temp=ymin
        
        result_D00_D10_temp=[]
        result_D20_temp=[]
        
        if class_of_damage=="D00":

            while y_temp<=ymax:
                while x_temp<=xmax:
                    grid_temp=search_point_grid_2(trapezoid,x_split,y_split,x_temp,y_temp,left_poly_line,right_poly_line)
                    if grid_temp==None:
                        pass
                    elif grid_temp in result_D00_D10_temp:
                        pass
                    else:
                        result_D00_D10_temp.append(grid_temp)
                    x_temp+=1
                y_temp+=1
                x_temp=xmin
        elif class_of_damage=="D10":

            while y_temp<=ymax:
                while x_temp<=xmax:
                    grid_temp=search_point_grid_2(trapezoid,x_split,y_split,x_temp,y_temp,left_poly_line,right_poly_line)
                    if grid_temp==None:
                        pass
                    elif grid_temp in result_D00_D10_temp:
                        pass
                    else:
                        result_D00_D10_temp.append(grid_temp)
                    x_temp+=1
                y_temp+=1
                x_temp=xmin
        elif class_of_damage=="D20":

            while y_temp<=ymax:
                while x_temp<=xmax:
                    grid_temp=search_point_grid_2(trapezoid,x_split,y_split,x_temp,y_temp,left_poly_line,right_poly_line)
                    if grid_temp==None:
                        pass
                    elif grid_temp in result_D20_temp:
                        pass
                    else:
                        result_D20_temp.append(grid_temp)
                    x_temp+=1
                y_temp+=1
                x_temp=xmin
        else:
            pass
        
        for j in range(0,len(result_D00_D10_temp)):
            grid_temp_2=result_D00_D10_temp[j]
            
            if grid_temp_2 in result_D20:
                pass
            elif grid_temp_2 in result_D00_D10:
                result_D20.append(grid_temp_2)
                result_D00_D10.remove(grid_temp_2)
            else:
                result_D00_D10.append(grid_temp_2)
        
        for k in range(0,len(result_D20_temp)):
            grid_temp_3=result_D20_temp[k]
            if grid_temp_3 in result_D20:
                pass
            elif grid_temp_3 in result_D00_D10:
                result_D20.append(grid_temp_3)
                result_D00_D10.remove(grid_temp_3)
            else:
                result_D20.append(grid_temp_3)
    
    print("重率0.6のグリッドは"+str(result_D00_D10)+"の"+str(len(result_D00_D10))+"箇所です")
    print("重率1のグリッドは"+str(result_D20)+"の"+str(len(result_D20))+"箇所です")
    crack_ratio=(0.6*len(result_D00_D10)+len(result_D20))/(x_split*y_split)
    return crack_ratio

# %%
def crack_ratio_2(trapezoids,i,x_split,y_split,left_poly_line,right_poly_line):
    
    temp=boundingboxes(i)
    trapezoid=trapezoids[i]
    
    crack_ratio=crack_ratio_calculate_2(trapezoid,temp,x_split,y_split,left_poly_line,right_poly_line)
    
    return crack_ratio

# %%
#print("ひび割れ率は"+str(crack_ratio(trapezoids,i,x_split,y_split))+"です")  

print("ひび割れ率は"+str(crack_ratio_2(trapezoids,i,x_split,y_split,left_poly_line,right_poly_line))+"です")


 
fig=plt.figure(figsize=(6,6))
img = draw_images_3(trapezoids,x_split,y_split,i,left_poly_line,right_poly_line)
plt.axis('on')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# Out:
# 重率0.6のグリッドは[]の0箇所です
# 重率1のグリッドは[]の0箇所です
# ひび割れ率は0.0です
